# %%
# Import the dependencies 
import pandas as pd
import numpy as np
from citipy import citipy
import requests
# Import the API key 
from config import weather_api_key
#(NOTE: copied Weather_Database Jupyter notebook file  and moved to it to the Weather_Database folder 
# AFTER saving the csv file to make accessing the API key more straightforward. 
# API key will not import from current notebook location)

# %%
# Create a zip of latitude and longitude pairs 
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
     # If the city is unique, then we will add it to the cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
# (using "enumerate() method will allow us to retrieve both the city name and the index from "city" list)
for i, city in enumerate(cities): 
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describe = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_describe})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | mount isa
# Processing Record 3 of Set 1 | saint-marc
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | tolaga bay
# Processing Record 18 of Set 1 | alta floresta
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | yarada
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | penzance
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 1 | longkou
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | maragogi
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | bemidji
# Processing Record 34 of Set 1 | quatre cocos
# Processing Record 35 of Set 1 | riyadh
# Processing Record 36 of Set 1 | tabukiniberu
# City not found. Skipping...
# Processing Record 37 of Set 1 | safford
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | mareeba
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | murray bridge
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | ngunguru
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | portland
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | devin
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | isangel
# Processing Record 6 of Set 2 | antigonish
# Processing Record 7 of Set 2 | bengkalis
# City not found. Skipping...
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | boende
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | taft
# Processing Record 12 of Set 2 | yining
# Processing Record 13 of Set 2 | shangzhi
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | konstantinovskiy
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 2 | swan river
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | khasan
# Processing Record 25 of Set 2 | dubrovka
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | uyuni
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | tonder
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | namibe
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | kimbe
# Processing Record 36 of Set 2 | manavgat
# Processing Record 37 of Set 2 | kushima
# Processing Record 38 of Set 2 | kenai
# Processing Record 39 of Set 2 | dawlatabad
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | bambanglipuro
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | san jeronimo
# Processing Record 44 of Set 2 | port hedland
# Processing Record 45 of Set 2 | wawa
# Processing Record 46 of Set 2 | touros
# Processing Record 47 of Set 2 | antsohihy
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | leshukonskoye
# Processing Record 50 of Set 2 | whitecourt
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | poniatowa
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | yei
# Processing Record 6 of Set 3 | saint-pierre
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | sulina
# Processing Record 9 of Set 3 | mayo
# Processing Record 10 of Set 3 | olafsvik
# Processing Record 11 of Set 3 | eyl
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | laiagam
# City not found. Skipping...
# Processing Record 14 of Set 3 | manzanillo
# Processing Record 15 of Set 3 | lakatoro
# Processing Record 16 of Set 3 | cockburn town
# Processing Record 17 of Set 3 | pontianak
# Processing Record 18 of Set 3 | baykit
# Processing Record 19 of Set 3 | vostok
# Processing Record 20 of Set 3 | thunder bay
# Processing Record 21 of Set 3 | dabat
# Processing Record 22 of Set 3 | amot
# Processing Record 23 of Set 3 | tautira
# Processing Record 24 of Set 3 | vestmannaeyjar
# Processing Record 25 of Set 3 | bullhead city
# Processing Record 26 of Set 3 | murgab
# Processing Record 27 of Set 3 | plastun
# Processing Record 28 of Set 3 | rocha
# Processing Record 29 of Set 3 | whitehorse
# Processing Record 30 of Set 3 | havre-saint-pierre
# Processing Record 31 of Set 3 | jashpurnagar
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | natitingou
# Processing Record 35 of Set 3 | hobart
# Processing Record 36 of Set 3 | makakilo city
# Processing Record 37 of Set 3 | iberia
# Processing Record 38 of Set 3 | tres arroyos
# Processing Record 39 of Set 3 | aksu
# Processing Record 40 of Set 3 | taranagar
# Processing Record 41 of Set 3 | turayf
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | silver city
# Processing Record 44 of Set 3 | bathsheba
# Processing Record 45 of Set 3 | luanda
# Processing Record 46 of Set 3 | kristiansund
# Processing Record 47 of Set 3 | gobabis
# Processing Record 48 of Set 3 | faya
# Processing Record 49 of Set 3 | andenes
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | maniitsoq
# Processing Record 2 of Set 4 | meulaboh
# Processing Record 3 of Set 4 | fare
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | batagay-alyta
# Processing Record 6 of Set 4 | carnarvon
# Processing Record 7 of Set 4 | san clemente
# Processing Record 8 of Set 4 | pundaguitan
# Processing Record 9 of Set 4 | kununurra
# Processing Record 10 of Set 4 | bolonchen
# City not found. Skipping...
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 4 | paz de ariporo
# City not found. Skipping...
# Processing Record 15 of Set 4 | mehamn
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | havelock
# Processing Record 18 of Set 4 | east london
# Processing Record 19 of Set 4 | dhamtari
# Processing Record 20 of Set 4 | kerema
# Processing Record 21 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | san cristobal
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | krasnoselkup
# Processing Record 26 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 4 | mahanoro
# Processing Record 28 of Set 4 | puerto escondido
# Processing Record 29 of Set 4 | sardarshahr
# Processing Record 30 of Set 4 | deputatskiy
# Processing Record 31 of Set 4 | brae
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | acapulco
# Processing Record 34 of Set 4 | bowen
# Processing Record 35 of Set 4 | jalu
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | tual
# Processing Record 38 of Set 4 | gubskaya
# Processing Record 39 of Set 4 | somerset
# Processing Record 40 of Set 4 | saryozek
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | sakakah
# Processing Record 43 of Set 4 | avera
# Processing Record 44 of Set 4 | kananga
# Processing Record 45 of Set 4 | tigil
# Processing Record 46 of Set 4 | dmitriyevskoye
# Processing Record 47 of Set 4 | camacha
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | shimoda
# Processing Record 50 of Set 4 | yola
# Processing Record 1 of Set 5 | taoudenni
# Processing Record 2 of Set 5 | hovd
# Processing Record 3 of Set 5 | bosaso
# Processing Record 4 of Set 5 | namtsy
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | narasapur
# Processing Record 8 of Set 5 | aripuana
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | sidhi
# Processing Record 11 of Set 5 | haines junction
# Processing Record 12 of Set 5 | pangnirtung
# Processing Record 13 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | kasongo
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | tselinnoye
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | cidreira
# Processing Record 24 of Set 5 | san pedro
# Processing Record 25 of Set 5 | omboue
# Processing Record 26 of Set 5 | lingao
# Processing Record 27 of Set 5 | muros
# Processing Record 28 of Set 5 | half moon bay
# Processing Record 29 of Set 5 | fortuna
# Processing Record 30 of Set 5 | labuhan
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | moramanga
# Processing Record 33 of Set 5 | alakurtti
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | binga
# Processing Record 36 of Set 5 | ancud
# Processing Record 37 of Set 5 | cerrito
# Processing Record 38 of Set 5 | stolin
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | arica
# Processing Record 42 of Set 5 | panguna
# Processing Record 43 of Set 5 | ratnapura
# Processing Record 44 of Set 5 | kamenka
# Processing Record 45 of Set 5 | ajra
# Processing Record 46 of Set 5 | port augusta
# Processing Record 47 of Set 5 | palmas
# Processing Record 48 of Set 5 | kommunisticheskiy
# Processing Record 49 of Set 5 | hue
# Processing Record 50 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 6 | armizonskoye
# Processing Record 2 of Set 6 | nabire
# Processing Record 3 of Set 6 | rodrigues alves
# Processing Record 4 of Set 6 | sur
# Processing Record 5 of Set 6 | charters towers
# Processing Record 6 of Set 6 | mehran
# Processing Record 7 of Set 6 | georgetown
# Processing Record 8 of Set 6 | mangrol
# Processing Record 9 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 6 | filadelfia
# Processing Record 11 of Set 6 | soloneshnoye
# Processing Record 12 of Set 6 | khakhea
# Processing Record 13 of Set 6 | saint-augustin
# Processing Record 14 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | tuatapere
# Processing Record 17 of Set 6 | samarai
# Processing Record 18 of Set 6 | corumba
# Processing Record 19 of Set 6 | atikokan
# Processing Record 20 of Set 6 | sambava
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | aguilas
# Processing Record 23 of Set 6 | wajir
# Processing Record 24 of Set 6 | dingle
# Processing Record 25 of Set 6 | phun phin
# City not found. Skipping...
# Processing Record 26 of Set 6 | novobiryusinskiy
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | cabedelo
# Processing Record 29 of Set 6 | houston
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | almonte
# Processing Record 32 of Set 6 | belorechensk
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | ndiekro
# City not found. Skipping...
# Processing Record 35 of Set 6 | aksarka
# Processing Record 36 of Set 6 | pitmoaga
# Processing Record 37 of Set 6 | kango
# Processing Record 38 of Set 6 | laurel
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | awbari
# Processing Record 41 of Set 6 | verkhnyaya maksakovka
# Processing Record 42 of Set 6 | iquitos
# Processing Record 43 of Set 6 | catia la mar
# Processing Record 44 of Set 6 | alice springs
# Processing Record 45 of Set 6 | ryotsu
# Processing Record 46 of Set 6 | waingapu
# Processing Record 47 of Set 6 | pevek
# Processing Record 48 of Set 6 | redcliffe
# Processing Record 49 of Set 6 | beloha
# Processing Record 50 of Set 6 | hauge
# Processing Record 1 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 2 of Set 7 | marzuq
# Processing Record 3 of Set 7 | grosseto
# Processing Record 4 of Set 7 | celestun
# Processing Record 5 of Set 7 | verkhoyansk
# Processing Record 6 of Set 7 | pimentel
# Processing Record 7 of Set 7 | port alfred
# Processing Record 8 of Set 7 | calama
# Processing Record 9 of Set 7 | tadine
# Processing Record 10 of Set 7 | madimba
# Processing Record 11 of Set 7 | great yarmouth
# Processing Record 12 of Set 7 | vila
# Processing Record 13 of Set 7 | sooke
# Processing Record 14 of Set 7 | eureka
# Processing Record 15 of Set 7 | kloulklubed
# Processing Record 16 of Set 7 | digby
# Processing Record 17 of Set 7 | chapais
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | palembang
# Processing Record 20 of Set 7 | manicore
# Processing Record 21 of Set 7 | takoradi
# Processing Record 22 of Set 7 | ndioum
# Processing Record 23 of Set 7 | puro
# Processing Record 24 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 7 | wangaratta
# Processing Record 26 of Set 7 | goderich
# Processing Record 27 of Set 7 | caudry
# Processing Record 28 of Set 7 | springdale
# Processing Record 29 of Set 7 | ndele
# Processing Record 30 of Set 7 | oranjestad
# Processing Record 31 of Set 7 | kralendijk
# Processing Record 32 of Set 7 | durban
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | bethel
# Processing Record 35 of Set 7 | biltine
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | lewes
# Processing Record 38 of Set 7 | mvomero
# Processing Record 39 of Set 7 | kokopo
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | katsuura
# Processing Record 42 of Set 7 | pirovskoye
# Processing Record 43 of Set 7 | cherskiy
# Processing Record 44 of Set 7 | usinsk
# Processing Record 45 of Set 7 | naze
# Processing Record 46 of Set 7 | fukue
# Processing Record 47 of Set 7 | dunedin
# Processing Record 48 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 7 | chokurdakh
# Processing Record 50 of Set 7 | broome
# Processing Record 1 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 2 of Set 8 | pochutla
# Processing Record 3 of Set 8 | udachnyy
# Processing Record 4 of Set 8 | mount darwin
# Processing Record 5 of Set 8 | port blair
# Processing Record 6 of Set 8 | kruisfontein
# Processing Record 7 of Set 8 | caracollo
# Processing Record 8 of Set 8 | athol
# Processing Record 9 of Set 8 | aloleng
# Processing Record 10 of Set 8 | stollberg
# Processing Record 11 of Set 8 | wichian buri
# Processing Record 12 of Set 8 | baguanos
# Processing Record 13 of Set 8 | eyrarbakki
# Processing Record 14 of Set 8 | longyearbyen
# Processing Record 15 of Set 8 | montepuez
# Processing Record 16 of Set 8 | tilichiki
# Processing Record 17 of Set 8 | kharp
# Processing Record 18 of Set 8 | nishihara
# Processing Record 19 of Set 8 | maldonado
# Processing Record 20 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 8 | conde
# Processing Record 22 of Set 8 | yerbogachen
# Processing Record 23 of Set 8 | severo-yeniseyskiy
# Processing Record 24 of Set 8 | kantang
# Processing Record 25 of Set 8 | gat
# Processing Record 26 of Set 8 | mao
# Processing Record 27 of Set 8 | erzin
# Processing Record 28 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 8 | smithers
# Processing Record 30 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 8 | gamba
# Processing Record 32 of Set 8 | diego de almagro
# Processing Record 33 of Set 8 | ahuimanu
# Processing Record 34 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 8 | synya
# Processing Record 36 of Set 8 | lavrentiya
# Processing Record 37 of Set 8 | killybegs
# Processing Record 38 of Set 8 | samana
# Processing Record 39 of Set 8 | turukhansk
# Processing Record 40 of Set 8 | okhotsk
# Processing Record 41 of Set 8 | gornopravdinsk
# Processing Record 42 of Set 8 | papara
# Processing Record 43 of Set 8 | ostrovnoy
# Processing Record 44 of Set 8 | raudeberg
# Processing Record 45 of Set 8 | bolshaya rechka
# Processing Record 46 of Set 8 | belyy yar
# Processing Record 47 of Set 8 | ouallam
# Processing Record 48 of Set 8 | mbalmayo
# Processing Record 49 of Set 8 | bull savanna
# Processing Record 50 of Set 8 | casambalangan
# Processing Record 1 of Set 9 | batesville
# Processing Record 2 of Set 9 | leningradskiy
# Processing Record 3 of Set 9 | san ignacio
# Processing Record 4 of Set 9 | wellington
# Processing Record 5 of Set 9 | panaba
# Processing Record 6 of Set 9 | ketchikan
# Processing Record 7 of Set 9 | grand-santi
# Processing Record 8 of Set 9 | mezen
# Processing Record 9 of Set 9 | namatanai
# Processing Record 10 of Set 9 | nacunday
# City not found. Skipping...
# Processing Record 11 of Set 9 | ambon
# Processing Record 12 of Set 9 | bonavista
# Processing Record 13 of Set 9 | buncrana
# Processing Record 14 of Set 9 | shakawe
# Processing Record 15 of Set 9 | gudari
# Processing Record 16 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 9 | kieta
# Processing Record 18 of Set 9 | aberdeen
# Processing Record 19 of Set 9 | dom pedrito
# Processing Record 20 of Set 9 | norman wells
# Processing Record 21 of Set 9 | tigzirt
# Processing Record 22 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 9 | antofagasta
# Processing Record 24 of Set 9 | tupik
# Processing Record 25 of Set 9 | oussouye
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | inuvik
# Processing Record 28 of Set 9 | mbale
# Processing Record 29 of Set 9 | maryborough
# Processing Record 30 of Set 9 | yumen
# Processing Record 31 of Set 9 | sandpoint
# Processing Record 32 of Set 9 | porbandar
# Processing Record 33 of Set 9 | matay
# Processing Record 34 of Set 9 | sabang
# Processing Record 35 of Set 9 | cajamarca
# Processing Record 36 of Set 9 | svetlaya
# Processing Record 37 of Set 9 | la peca
# Processing Record 38 of Set 9 | lorengau
# Processing Record 39 of Set 9 | atar
# Processing Record 40 of Set 9 | hernani
# Processing Record 41 of Set 9 | yenagoa
# Processing Record 42 of Set 9 | rio grande
# Processing Record 43 of Set 9 | tomisato
# Processing Record 44 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 9 | emba
# Processing Record 47 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set 9 | brigantine
# Processing Record 49 of Set 9 | vardo
# Processing Record 50 of Set 9 | umm lajj
# Processing Record 1 of Set 10 | laguna
# Processing Record 2 of Set 10 | asau
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | san quintin
# Processing Record 5 of Set 10 | foki
# Processing Record 6 of Set 10 | alofi
# Processing Record 7 of Set 10 | labuan
# Processing Record 8 of Set 10 | puerto madryn
# Processing Record 9 of Set 10 | barra
# Processing Record 10 of Set 10 | hobyo
# Processing Record 11 of Set 10 | port-gentil
# Processing Record 12 of Set 10 | ciudad del maiz
# Processing Record 13 of Set 10 | buchanan
# Processing Record 14 of Set 10 | katherine
# Processing Record 15 of Set 10 | abalak
# Processing Record 16 of Set 10 | woodbury
# Processing Record 17 of Set 10 | tiksi
# Processing Record 18 of Set 10 | shingu
# Processing Record 19 of Set 10 | clyde river
# Processing Record 20 of Set 10 | vila velha
# Processing Record 21 of Set 10 | qandala
# Processing Record 22 of Set 10 | barcelos
# Processing Record 23 of Set 10 | mayumba
# Processing Record 24 of Set 10 | akhaldaba
# Processing Record 25 of Set 10 | chunoyar
# Processing Record 26 of Set 10 | ust-ilimsk
# Processing Record 27 of Set 10 | alghero
# Processing Record 28 of Set 10 | hamilton
# Processing Record 29 of Set 10 | manado
# Processing Record 30 of Set 10 | hualmay
# Processing Record 31 of Set 10 | nha trang
# Processing Record 32 of Set 10 | gimli
# Processing Record 33 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 10 | kalabo
# Processing Record 35 of Set 10 | ciudad bolivar
# Processing Record 36 of Set 10 | birobidzhan
# Processing Record 37 of Set 10 | zaria
# Processing Record 38 of Set 10 | panama city
# Processing Record 39 of Set 10 | kungurtug
# Processing Record 40 of Set 10 | kawalu
# Processing Record 41 of Set 10 | jodhpur
# Processing Record 42 of Set 10 | acari
# Processing Record 43 of Set 10 | wasilla
# Processing Record 44 of Set 10 | mitsamiouli
# Processing Record 45 of Set 10 | puerto quijarro
# Processing Record 46 of Set 10 | zemio
# Processing Record 47 of Set 10 | shahpur
# Processing Record 48 of Set 10 | korla
# Processing Record 49 of Set 10 | tessalit
# Processing Record 50 of Set 10 | biak
# Processing Record 1 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 11 | port macquarie
# Processing Record 3 of Set 11 | victoria point
# Processing Record 4 of Set 11 | kuznechnoye
# Processing Record 5 of Set 11 | orsha
# Processing Record 6 of Set 11 | sharjah
# Processing Record 7 of Set 11 | cozumel
# Processing Record 8 of Set 11 | chieti
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | mopipi
# Processing Record 11 of Set 11 | vestmanna
# Processing Record 12 of Set 11 | maarianhamina
# Processing Record 13 of Set 11 | tezu
# Processing Record 14 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 15 of Set 11 | itoman
# Processing Record 16 of Set 11 | kampot
# Processing Record 17 of Set 11 | tarauaca
# Processing Record 18 of Set 11 | zhigansk
# Processing Record 19 of Set 11 | batemans bay
# Processing Record 20 of Set 11 | gao
# Processing Record 21 of Set 11 | garmsar
# Processing Record 22 of Set 11 | matadi
# Processing Record 23 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 24 of Set 11 | hambantota
# Processing Record 25 of Set 11 | linxia
# Processing Record 26 of Set 11 | palmer
# Processing Record 27 of Set 11 | nakajo
# City not found. Skipping...
# Processing Record 28 of Set 11 | muisne
# Processing Record 29 of Set 11 | buala
# Processing Record 30 of Set 11 | masallatah
# Processing Record 31 of Set 11 | daru
# Processing Record 32 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 11 | bushehr
# Processing Record 34 of Set 11 | davila
# Processing Record 35 of Set 11 | monticello
# Processing Record 36 of Set 11 | havoysund
# Processing Record 37 of Set 11 | chibombo
# Processing Record 38 of Set 11 | esil
# Processing Record 39 of Set 11 | nuuk
# Processing Record 40 of Set 11 | necochea
# Processing Record 41 of Set 11 | denpasar
# Processing Record 42 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 11 | sarangani
# Processing Record 44 of Set 11 | santa marta
# Processing Record 45 of Set 11 | baragua
# Processing Record 46 of Set 11 | pangkalanbuun
# Processing Record 47 of Set 11 | panjab
# Processing Record 48 of Set 11 | najran
# Processing Record 49 of Set 11 | berdigestyakh
# Processing Record 50 of Set 11 | liling
# Processing Record 1 of Set 12 | kuito
# Processing Record 2 of Set 12 | bahia honda
# Processing Record 3 of Set 12 | qaqortoq
# Processing Record 4 of Set 12 | miri
# Processing Record 5 of Set 12 | kirakira
# Processing Record 6 of Set 12 | maryville
# Processing Record 7 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 8 of Set 12 | vanino
# Processing Record 9 of Set 12 | talaya
# Processing Record 10 of Set 12 | san juan
# Processing Record 11 of Set 12 | tubuala
# Processing Record 12 of Set 12 | yaan
# Processing Record 13 of Set 12 | saint-georges
# Processing Record 14 of Set 12 | majene
# Processing Record 15 of Set 12 | sibolga
# Processing Record 16 of Set 12 | poronaysk
# Processing Record 17 of Set 12 | the valley
# Processing Record 18 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 12 | broken hill
# Processing Record 20 of Set 12 | vao
# Processing Record 21 of Set 12 | salina
# Processing Record 22 of Set 12 | nikki
# Processing Record 23 of Set 12 | wanlaweyn
# Processing Record 24 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 25 of Set 12 | coquimbo
# Processing Record 26 of Set 12 | eenhana
# Processing Record 27 of Set 12 | bellview
# Processing Record 28 of Set 12 | cusset
# Processing Record 29 of Set 12 | molchanovo
# Processing Record 30 of Set 12 | zorgo
# Processing Record 31 of Set 12 | jasper
# Processing Record 32 of Set 12 | zabaykalsk
# Processing Record 33 of Set 12 | mazyr
# Processing Record 34 of Set 12 | marawi
# Processing Record 35 of Set 12 | floro
# Processing Record 36 of Set 12 | vanimo
# Processing Record 37 of Set 12 | bilibino
# Processing Record 38 of Set 12 | victor harbor
# Processing Record 39 of Set 12 | igarka
# Processing Record 40 of Set 12 | lazaro cardenas
# Processing Record 41 of Set 12 | egvekinot
# Processing Record 42 of Set 12 | antibes
# Processing Record 43 of Set 12 | aden
# Processing Record 44 of Set 12 | makat
# Processing Record 45 of Set 12 | casino
# Processing Record 46 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 47 of Set 12 | beringovskiy
# Processing Record 48 of Set 12 | nadadores
# Processing Record 49 of Set 12 | serebryansk
# Processing Record 50 of Set 12 | maun
# Processing Record 1 of Set 13 | gokak
# Processing Record 2 of Set 13 | beira
# Processing Record 3 of Set 13 | lingyuan
# Processing Record 4 of Set 13 | pisco
# Processing Record 5 of Set 13 | serov
# Processing Record 6 of Set 13 | dalby
# Processing Record 7 of Set 13 | sawtell
# Processing Record 8 of Set 13 | saldanha
# Processing Record 9 of Set 13 | dragor
# Processing Record 10 of Set 13 | huinan
# Processing Record 11 of Set 13 | moron
# Processing Record 12 of Set 13 | marsa matruh
# Processing Record 13 of Set 13 | baruun-urt
# Processing Record 14 of Set 13 | nome
# Processing Record 15 of Set 13 | rabo de peixe
# Processing Record 16 of Set 13 | yulara
# Processing Record 17 of Set 13 | nemuro
# Processing Record 18 of Set 13 | tombouctou
# Processing Record 19 of Set 13 | harnosand
# Processing Record 20 of Set 13 | yarmouth
# Processing Record 21 of Set 13 | iralaya
# Processing Record 22 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 13 | campbell river
# Processing Record 25 of Set 13 | dauphin
# Processing Record 26 of Set 13 | koltubanovskiy
# Processing Record 27 of Set 13 | sechelt
# Processing Record 28 of Set 13 | bereda
# Processing Record 29 of Set 13 | imbituba
# Processing Record 30 of Set 13 | winsum
# Processing Record 31 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 32 of Set 13 | bhalki
# Processing Record 33 of Set 13 | camanci
# City not found. Skipping...
# Processing Record 34 of Set 13 | kez
# Processing Record 35 of Set 13 | petatlan
# Processing Record 36 of Set 13 | berlevag
# Processing Record 37 of Set 13 | kavaratti
# Processing Record 38 of Set 13 | chernyshevskiy
# Processing Record 39 of Set 13 | oktyabrskiy
# Processing Record 40 of Set 13 | banjar
# Processing Record 41 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 13 | lampa
# Processing Record 43 of Set 13 | severodvinsk
# Processing Record 44 of Set 13 | aksha
# Processing Record 45 of Set 13 | opuwo
# Processing Record 46 of Set 13 | baikunthpur
# Processing Record 47 of Set 13 | port moresby
# Processing Record 48 of Set 13 | belmonte
# Processing Record 49 of Set 13 | bonthe
# Processing Record 50 of Set 13 | manavalakurichi
# Processing Record 1 of Set 14 | constitucion
# Processing Record 2 of Set 14 | monrovia
# Processing Record 3 of Set 14 | vereshchagino
# Processing Record 4 of Set 14 | middle island
# Processing Record 5 of Set 14 | matara
# Processing Record 6 of Set 14 | chenghai
# Processing Record 7 of Set 14 | iroquois falls
# Processing Record 8 of Set 14 | khash
# Processing Record 9 of Set 14 | wichita falls
# Processing Record 10 of Set 14 | mangai
# Processing Record 11 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 14 | northam
# Processing Record 13 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 14 | sigli
# Processing Record 15 of Set 14 | trairi
# Processing Record 16 of Set 14 | upington
# Processing Record 17 of Set 14 | haverfordwest
# Processing Record 18 of Set 14 | teguise
# Processing Record 19 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 20 of Set 14 | amahai
# Processing Record 21 of Set 14 | gravdal
# Processing Record 22 of Set 14 | ilebo
# Processing Record 23 of Set 14 | gold coast
# Processing Record 24 of Set 14 | westport
# Processing Record 25 of Set 14 | durango
# Processing Record 26 of Set 14 | sinnamary
# Processing Record 27 of Set 14 | nara
# Processing Record 28 of Set 14 | tazmalt
# Processing Record 29 of Set 14 | san fernando
# Processing Record 30 of Set 14 | saint-leu
# Processing Record 31 of Set 14 | orlik
# Processing Record 32 of Set 14 | macamic
# Processing Record 33 of Set 14 | bandarbeyla
# Processing Record 34 of Set 14 | itapetinga
# Processing Record 35 of Set 14 | evensk
# Processing Record 36 of Set 14 | watertown
# Processing Record 37 of Set 14 | banda aceh
# Processing Record 38 of Set 14 | nago
# Processing Record 39 of Set 14 | skibbereen
# Processing Record 40 of Set 14 | iracoubo
# Processing Record 41 of Set 14 | moroni
# Processing Record 42 of Set 14 | thomaston
# Processing Record 43 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 44 of Set 14 | port-cartier
# Processing Record 45 of Set 14 | mirnyy
# Processing Record 46 of Set 14 | akyab
# Processing Record 47 of Set 14 | qasigiannguit
# Processing Record 48 of Set 14 | weligama
# Processing Record 49 of Set 14 | taksimo
# Processing Record 50 of Set 14 | oktyabrskoye
# Processing Record 1 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 15 | harlow
# Processing Record 3 of Set 15 | artigas
# Processing Record 4 of Set 15 | te anau
# Processing Record 5 of Set 15 | guymon
# Processing Record 6 of Set 15 | butajira
# Processing Record 7 of Set 15 | roma
# Processing Record 8 of Set 15 | camacupa
# Processing Record 9 of Set 15 | mantua
# Processing Record 10 of Set 15 | khandbari
# Processing Record 11 of Set 15 | nkan
# Processing Record 12 of Set 15 | pouembout
# Processing Record 13 of Set 15 | qui nhon
# Processing Record 14 of Set 15 | san joaquin
# Processing Record 15 of Set 15 | huron
# Processing Record 16 of Set 15 | remedios
# Processing Record 17 of Set 15 | manger
# Processing Record 18 of Set 15 | cascais
# Processing Record 19 of Set 15 | kefamenanu
# Processing Record 20 of Set 15 | ellon
# Processing Record 21 of Set 15 | rio gallegos
# Processing Record 22 of Set 15 | ca mau
# Processing Record 23 of Set 15 | la joya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Sao Joao Da Barra      BR -21.6403  -41.0511     86.00        58
# 1          Mount Isa      AU -20.7333  139.5000     73.40        16
# 2         Saint-Marc      HT  19.1082  -72.6938     82.02        61
# 3             Lompoc      US  34.6391 -120.4579     60.80        55
# 4             Atuona      PF  -9.8000 -139.0333     80.06        72
# 5            Qaanaaq      GL  77.4840  -69.3632    -23.57        69
# 6            Ahipara      NZ -35.1667  173.1667     65.05        83
# 7         Butaritari      KI   3.0707  172.7902     81.59        79
# 8          Geraldton      AU -28.7667  114.6000     68.00        94
# 9          Cape Town      ZA -33.9258   18.4232     68.00        63
#
#    Cloudiness  Wind Speed Current Description
# 0           0       16.11           clear sky
# 1          17       10.36          few clouds
# 2          15       10.63          few clouds
# 3          20        9.22          few clouds
# 4           2       12.33           clear sky
# 5           0        9.06           clear sky
# 6           4        2.86           clear sky
# 7          81       19.01       broken clouds
# 8           0        9.22           clear sky
# 9          20       11.50          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
