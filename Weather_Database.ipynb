# %%
# Import the dependencies 
import pandas as pd
import numpy as np
from citipy import citipy
import requests
# Import the API key 
from config import weather_api_key
#(NOTE: copied Weather_Database Jupyter notebook file  and moved to it to the Weather_Database folder 
# AFTER saving the csv file to make accessing the API key more straightforward. 
# API key will not import from current notebook location)

# %%
# Create a zip of latitude and longitude pairs 
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
     # If the city is unique, then we will add it to the cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
# (using "enumerate() method will allow us to retrieve both the city name and the index from "city" list)
for i, city in enumerate(cities): 
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describe = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_describe})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upata
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | yaan
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | chaa-khol
# City not found. Skipping...
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | tura
# Processing Record 20 of Set 1 | beloha
# Processing Record 21 of Set 1 | srednekolymsk
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | bertoua
# Processing Record 24 of Set 1 | natuba
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | kudahuvadhoo
# Processing Record 29 of Set 1 | waddan
# Processing Record 30 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 1 | acajutla
# Processing Record 32 of Set 1 | coihaique
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | sur
# Processing Record 35 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 1 | dunedin
# Processing Record 37 of Set 1 | fort morgan
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | malanje
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | darnah
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | kokopo
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | aksarka
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | zaysan
# Processing Record 5 of Set 2 | katobu
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | santa rosa del sur
# Processing Record 10 of Set 2 | agirish
# Processing Record 11 of Set 2 | manuk mangkaw
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | iqaluit
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | dauriya
# Processing Record 17 of Set 2 | broome
# Processing Record 18 of Set 2 | cukai
# Processing Record 19 of Set 2 | muyezerskiy
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | zhoukou
# Processing Record 22 of Set 2 | husavik
# Processing Record 23 of Set 2 | micheweni
# Processing Record 24 of Set 2 | yar-sale
# Processing Record 25 of Set 2 | ciudad bolivar
# Processing Record 26 of Set 2 | mount isa
# Processing Record 27 of Set 2 | sechura
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | biak
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | eyl
# Processing Record 32 of Set 2 | vao
# Processing Record 33 of Set 2 | kloulklubed
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | maceio
# Processing Record 38 of Set 2 | kars
# Processing Record 39 of Set 2 | tomorkeny
# Processing Record 40 of Set 2 | adrar
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | sun city west
# Processing Record 43 of Set 2 | otane
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | pitsunda
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | ilfracombe
# Processing Record 49 of Set 2 | nyurba
# Processing Record 50 of Set 2 | verkhoyansk
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | loubomo
# Processing Record 3 of Set 3 | ambon
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | plainview
# Processing Record 6 of Set 3 | hami
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | nadym
# Processing Record 9 of Set 3 | te anau
# Processing Record 10 of Set 3 | brodokalmak
# Processing Record 11 of Set 3 | arroio grande
# Processing Record 12 of Set 3 | gunjur
# Processing Record 13 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 3 | kholodnyy
# Processing Record 15 of Set 3 | vila do maio
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | lima
# Processing Record 18 of Set 3 | vila franca do campo
# Processing Record 19 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | buraydah
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | verbilki
# Processing Record 25 of Set 3 | yellowknife
# Processing Record 26 of Set 3 | mongo
# Processing Record 27 of Set 3 | lata
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | laguna
# Processing Record 31 of Set 3 | shorkot
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | lithakia
# Processing Record 36 of Set 3 | tahlequah
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | svetlaya
# Processing Record 39 of Set 3 | port blair
# Processing Record 40 of Set 3 | skelleftea
# Processing Record 41 of Set 3 | conselheiro pena
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | kenitra
# Processing Record 44 of Set 3 | waipawa
# Processing Record 45 of Set 3 | tieling
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 48 of Set 3 | ukmerge
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | port macquarie
# Processing Record 9 of Set 4 | okhotsk
# Processing Record 10 of Set 4 | mar del plata
# Processing Record 11 of Set 4 | tiznit
# Processing Record 12 of Set 4 | saint-francois
# Processing Record 13 of Set 4 | saint-louis
# Processing Record 14 of Set 4 | deputatskiy
# Processing Record 15 of Set 4 | tornio
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | samarai
# Processing Record 18 of Set 4 | port hedland
# Processing Record 19 of Set 4 | haifa
# Processing Record 20 of Set 4 | itoman
# Processing Record 21 of Set 4 | ozu
# Processing Record 22 of Set 4 | komsomolskiy
# Processing Record 23 of Set 4 | luwuk
# Processing Record 24 of Set 4 | grandview
# Processing Record 25 of Set 4 | edson
# Processing Record 26 of Set 4 | am timan
# Processing Record 27 of Set 4 | aquiraz
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | atyrau
# Processing Record 30 of Set 4 | lerwick
# Processing Record 31 of Set 4 | yanliang
# Processing Record 32 of Set 4 | korla
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | vallenar
# Processing Record 35 of Set 4 | acapulco
# Processing Record 36 of Set 4 | baie-comeau
# Processing Record 37 of Set 4 | fayaoue
# Processing Record 38 of Set 4 | spanish town
# Processing Record 39 of Set 4 | leninskoye
# Processing Record 40 of Set 4 | ranau
# Processing Record 41 of Set 4 | la baneza
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | chopinzinho
# Processing Record 44 of Set 4 | ambilobe
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | hegang
# Processing Record 47 of Set 4 | dossor
# Processing Record 48 of Set 4 | nayoro
# Processing Record 49 of Set 4 | havre-saint-pierre
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | aykhal
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | stykkisholmur
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | joao pinheiro
# Processing Record 7 of Set 5 | zorritos
# Processing Record 8 of Set 5 | el retorno
# Processing Record 9 of Set 5 | gravdal
# Processing Record 10 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 5 | egvekinot
# Processing Record 12 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 13 of Set 5 | natal
# Processing Record 14 of Set 5 | cockburn town
# Processing Record 15 of Set 5 | doha
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | mumford
# Processing Record 18 of Set 5 | kutum
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | pochutla
# Processing Record 22 of Set 5 | maningrida
# Processing Record 23 of Set 5 | isiro
# Processing Record 24 of Set 5 | ilhabela
# Processing Record 25 of Set 5 | aubenas
# Processing Record 26 of Set 5 | pangody
# Processing Record 27 of Set 5 | chicama
# Processing Record 28 of Set 5 | dikson
# Processing Record 29 of Set 5 | port alfred
# Processing Record 30 of Set 5 | krapivinskiy
# Processing Record 31 of Set 5 | olga
# Processing Record 32 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | lakes entrance
# Processing Record 34 of Set 5 | tarime
# Processing Record 35 of Set 5 | basco
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | tabuk
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | yeppoon
# Processing Record 41 of Set 5 | kavaratti
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | la orilla
# Processing Record 45 of Set 5 | aksu
# Processing Record 46 of Set 5 | linjiang
# Processing Record 47 of Set 5 | jinchang
# Processing Record 48 of Set 5 | miri
# Processing Record 49 of Set 5 | lorengau
# Processing Record 50 of Set 5 | bimbo
# Processing Record 1 of Set 6 | mahebourg
# Processing Record 2 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 6 | mareeba
# Processing Record 4 of Set 6 | port keats
# Processing Record 5 of Set 6 | taikang
# Processing Record 6 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 7 of Set 6 | la rioja
# Processing Record 8 of Set 6 | bend
# Processing Record 9 of Set 6 | oranjemund
# Processing Record 10 of Set 6 | sohna
# Processing Record 11 of Set 6 | nara
# Processing Record 12 of Set 6 | anadyr
# Processing Record 13 of Set 6 | ostrovnoy
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | oussouye
# Processing Record 16 of Set 6 | the pas
# Processing Record 17 of Set 6 | portobelo
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | snezhnogorsk
# Processing Record 20 of Set 6 | conceicao do araguaia
# Processing Record 21 of Set 6 | noyabrsk
# Processing Record 22 of Set 6 | oktyabrskiy
# Processing Record 23 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | saucillo
# Processing Record 26 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 6 | san carlos de bariloche
# Processing Record 28 of Set 6 | ulaanbaatar
# Processing Record 29 of Set 6 | pevek
# Processing Record 30 of Set 6 | kahului
# Processing Record 31 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 6 | itarema
# Processing Record 33 of Set 6 | manasa
# Processing Record 34 of Set 6 | hervey bay
# Processing Record 35 of Set 6 | inirida
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | bilma
# Processing Record 38 of Set 6 | miramar
# Processing Record 39 of Set 6 | neiafu
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 42 of Set 6 | khandyga
# Processing Record 43 of Set 6 | dale
# Processing Record 44 of Set 6 | mpika
# Processing Record 45 of Set 6 | gelemso
# Processing Record 46 of Set 6 | kampene
# Processing Record 47 of Set 6 | longyearbyen
# Processing Record 48 of Set 6 | sulphur springs
# Processing Record 49 of Set 6 | hualmay
# Processing Record 50 of Set 6 | uray
# Processing Record 1 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | zwedru
# Processing Record 3 of Set 7 | pinawa
# Processing Record 4 of Set 7 | montepuez
# Processing Record 5 of Set 7 | port antonio
# Processing Record 6 of Set 7 | puerto escondido
# Processing Record 7 of Set 7 | coquimbo
# Processing Record 8 of Set 7 | north bend
# Processing Record 9 of Set 7 | olafsvik
# Processing Record 10 of Set 7 | graham
# Processing Record 11 of Set 7 | bolshaya dzhalga
# Processing Record 12 of Set 7 | bowen
# Processing Record 13 of Set 7 | shenjiamen
# Processing Record 14 of Set 7 | havelock
# Processing Record 15 of Set 7 | saint-pierre
# Processing Record 16 of Set 7 | zambezi
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | doctor arroyo
# Processing Record 19 of Set 7 | elizabeth city
# Processing Record 20 of Set 7 | san cristobal
# Processing Record 21 of Set 7 | ballina
# Processing Record 22 of Set 7 | tual
# Processing Record 23 of Set 7 | khislavichi
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | saint anthony
# Processing Record 26 of Set 7 | roma
# Processing Record 27 of Set 7 | rio verde de mato grosso
# Processing Record 28 of Set 7 | tigil
# Processing Record 29 of Set 7 | leeuwarden
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | victoria
# Processing Record 32 of Set 7 | taree
# Processing Record 33 of Set 7 | makakilo city
# Processing Record 34 of Set 7 | mahajanga
# Processing Record 35 of Set 7 | bontang
# Processing Record 36 of Set 7 | cidreira
# Processing Record 37 of Set 7 | esmeraldas
# Processing Record 38 of Set 7 | labuhan
# Processing Record 39 of Set 7 | santa maria
# Processing Record 40 of Set 7 | grabouw
# Processing Record 41 of Set 7 | krasyliv
# Processing Record 42 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 7 | cherskiy
# Processing Record 44 of Set 7 | aguimes
# Processing Record 45 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 46 of Set 7 | emerald
# Processing Record 47 of Set 7 | batagay-alyta
# Processing Record 48 of Set 7 | konya
# Processing Record 49 of Set 7 | zalantun
# Processing Record 50 of Set 7 | ishigaki
# Processing Record 1 of Set 8 | kiruna
# Processing Record 2 of Set 8 | ternate
# Processing Record 3 of Set 8 | hazorasp
# Processing Record 4 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 8 | partizansk
# Processing Record 6 of Set 8 | nelson
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | salalah
# Processing Record 9 of Set 8 | sambava
# Processing Record 10 of Set 8 | cururupu
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | buala
# Processing Record 13 of Set 8 | colac
# Processing Record 14 of Set 8 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 15 of Set 8 | hamilton
# Processing Record 16 of Set 8 | seoul
# Processing Record 17 of Set 8 | ahipara
# Processing Record 18 of Set 8 | sao joao da barra
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | assiniboia
# Processing Record 21 of Set 8 | broken hill
# Processing Record 22 of Set 8 | novikovo
# Processing Record 23 of Set 8 | salta
# Processing Record 24 of Set 8 | pangnirtung
# Processing Record 25 of Set 8 | abha
# Processing Record 26 of Set 8 | juneau
# Processing Record 27 of Set 8 | sanger
# Processing Record 28 of Set 8 | san lorenzo
# Processing Record 29 of Set 8 | whitehorse
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | itanagar
# Processing Record 32 of Set 8 | san vicente
# Processing Record 33 of Set 8 | maldonado
# Processing Record 34 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 35 of Set 8 | rocha
# Processing Record 36 of Set 8 | torbay
# Processing Record 37 of Set 8 | harper
# Processing Record 38 of Set 8 | varzea da palma
# Processing Record 39 of Set 8 | rawson
# Processing Record 40 of Set 8 | along
# Processing Record 41 of Set 8 | cabedelo
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | bar harbor
# Processing Record 44 of Set 8 | dovolnoye
# Processing Record 45 of Set 8 | altay
# Processing Record 46 of Set 8 | tautira
# Processing Record 47 of Set 8 | campos belos
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | prince george
# Processing Record 50 of Set 8 | solnechnyy
# Processing Record 1 of Set 9 | sorland
# Processing Record 2 of Set 9 | oktyabrskoye
# Processing Record 3 of Set 9 | dingzhou
# Processing Record 4 of Set 9 | santiago
# Processing Record 5 of Set 9 | saint-georges
# Processing Record 6 of Set 9 | provideniya
# Processing Record 7 of Set 9 | lannion
# Processing Record 8 of Set 9 | lixourion
# Processing Record 9 of Set 9 | porto novo
# Processing Record 10 of Set 9 | rivas
# Processing Record 11 of Set 9 | camacha
# Processing Record 12 of Set 9 | manyana
# Processing Record 13 of Set 9 | imeni poliny osipenko
# Processing Record 14 of Set 9 | kralendijk
# Processing Record 15 of Set 9 | maua
# Processing Record 16 of Set 9 | khvorostyanka
# Processing Record 17 of Set 9 | linxia
# Processing Record 18 of Set 9 | naranjal
# Processing Record 19 of Set 9 | vila velha
# Processing Record 20 of Set 9 | guarapari
# Processing Record 21 of Set 9 | rurrenabaque
# Processing Record 22 of Set 9 | medea
# Processing Record 23 of Set 9 | araouane
# Processing Record 24 of Set 9 | caluquembe
# Processing Record 25 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 9 | pljevlja
# Processing Record 27 of Set 9 | maragogi
# Processing Record 28 of Set 9 | loandjili
# Processing Record 29 of Set 9 | kindersley
# Processing Record 30 of Set 9 | nelson bay
# Processing Record 31 of Set 9 | orlik
# Processing Record 32 of Set 9 | the valley
# Processing Record 33 of Set 9 | severo-kurilsk
# Processing Record 34 of Set 9 | comodoro rivadavia
# Processing Record 35 of Set 9 | boyolangu
# Processing Record 36 of Set 9 | vila
# Processing Record 37 of Set 9 | kosh-agach
# Processing Record 38 of Set 9 | boshkengash
# Processing Record 39 of Set 9 | qinhuangdao
# Processing Record 40 of Set 9 | san juan
# Processing Record 41 of Set 9 | quang ngai
# Processing Record 42 of Set 9 | ostersund
# Processing Record 43 of Set 9 | muli
# Processing Record 44 of Set 9 | north platte
# Processing Record 45 of Set 9 | saint andrews
# Processing Record 46 of Set 9 | brae
# Processing Record 47 of Set 9 | santana do acarau
# Processing Record 48 of Set 9 | fernie
# Processing Record 49 of Set 9 | lewiston
# Processing Record 50 of Set 9 | los llanos de aridane
# Processing Record 1 of Set 10 | koyelga
# Processing Record 2 of Set 10 | ust-kuyga
# Processing Record 3 of Set 10 | mirnyy
# Processing Record 4 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 10 | harnosand
# Processing Record 6 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 10 | nuuk
# Processing Record 9 of Set 10 | dubti
# Processing Record 10 of Set 10 | beamsville
# Processing Record 11 of Set 10 | arua
# Processing Record 12 of Set 10 | victoria point
# Processing Record 13 of Set 10 | krasnogvardeyskoye
# Processing Record 14 of Set 10 | dingle
# Processing Record 15 of Set 10 | durban
# Processing Record 16 of Set 10 | carnarvon
# Processing Record 17 of Set 10 | bilibino
# Processing Record 18 of Set 10 | san patricio
# Processing Record 19 of Set 10 | champerico
# Processing Record 20 of Set 10 | banff
# Processing Record 21 of Set 10 | camabatela
# Processing Record 22 of Set 10 | sault sainte marie
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | khovu-aksy
# Processing Record 25 of Set 10 | san pedro
# Processing Record 26 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 27 of Set 10 | half moon bay
# Processing Record 28 of Set 10 | tucurui
# Processing Record 29 of Set 10 | olinda
# Processing Record 30 of Set 10 | svetlyy
# Processing Record 31 of Set 10 | mastic beach
# Processing Record 32 of Set 10 | kambove
# Processing Record 33 of Set 10 | koungou
# Processing Record 34 of Set 10 | lodja
# Processing Record 35 of Set 10 | salihorsk
# Processing Record 36 of Set 10 | prevalje
# Processing Record 37 of Set 10 | west bay
# Processing Record 38 of Set 10 | camana
# Processing Record 39 of Set 10 | missoula
# Processing Record 40 of Set 10 | porbandar
# Processing Record 41 of Set 10 | soe
# Processing Record 42 of Set 10 | roald
# Processing Record 43 of Set 10 | marzuq
# Processing Record 44 of Set 10 | alta floresta
# Processing Record 45 of Set 10 | shimanovsk
# Processing Record 46 of Set 10 | richards bay
# Processing Record 47 of Set 10 | golden
# Processing Record 48 of Set 10 | zhangye
# Processing Record 49 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 50 of Set 10 | mesopotamia
# Processing Record 1 of Set 11 | hambantota
# Processing Record 2 of Set 11 | gemena
# Processing Record 3 of Set 11 | minggang
# Processing Record 4 of Set 11 | rosetta
# Processing Record 5 of Set 11 | nuevo progreso
# Processing Record 6 of Set 11 | esperance
# Processing Record 7 of Set 11 | telhara
# Processing Record 8 of Set 11 | quzhou
# Processing Record 9 of Set 11 | la ronge
# Processing Record 10 of Set 11 | sioux lookout
# Processing Record 11 of Set 11 | boende
# Processing Record 12 of Set 11 | mitsamiouli
# Processing Record 13 of Set 11 | fortuna
# Processing Record 14 of Set 11 | portland
# Processing Record 15 of Set 11 | champoton
# Processing Record 16 of Set 11 | weligama
# Processing Record 17 of Set 11 | lavrentiya
# Processing Record 18 of Set 11 | berlevag
# Processing Record 19 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 11 | karakol
# Processing Record 21 of Set 11 | severo-yeniseyskiy
# Processing Record 22 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 23 of Set 11 | beringovskiy
# Processing Record 24 of Set 11 | brawley
# Processing Record 25 of Set 11 | shingu
# Processing Record 26 of Set 11 | shediac
# Processing Record 27 of Set 11 | nortelandia
# Processing Record 28 of Set 11 | filingue
# Processing Record 29 of Set 11 | bulungu
# Processing Record 30 of Set 11 | novo aripuana
# Processing Record 31 of Set 11 | abnub
# Processing Record 32 of Set 11 | dudinka
# Processing Record 33 of Set 11 | nhulunbuy
# Processing Record 34 of Set 11 | hit
# Processing Record 35 of Set 11 | amapa
# Processing Record 36 of Set 11 | seddon
# Processing Record 37 of Set 11 | grand gaube
# Processing Record 38 of Set 11 | san quintin
# Processing Record 39 of Set 11 | moron
# Processing Record 40 of Set 11 | patos de minas
# Processing Record 41 of Set 11 | griffith
# Processing Record 42 of Set 11 | kailua
# Processing Record 43 of Set 11 | hengshui
# Processing Record 44 of Set 11 | olean
# Processing Record 45 of Set 11 | yongan
# Processing Record 46 of Set 11 | duekoue
# Processing Record 47 of Set 11 | kisangani
# Processing Record 48 of Set 11 | sesheke
# Processing Record 49 of Set 11 | ogdensburg
# Processing Record 50 of Set 11 | nioro
# Processing Record 1 of Set 12 | opuwo
# Processing Record 2 of Set 12 | kaele
# Processing Record 3 of Set 12 | nome
# Processing Record 4 of Set 12 | necochea
# Processing Record 5 of Set 12 | cadereyta
# Processing Record 6 of Set 12 | bikin
# Processing Record 7 of Set 12 | hendek
# Processing Record 8 of Set 12 | negombo
# Processing Record 9 of Set 12 | port hardy
# Processing Record 10 of Set 12 | russell
# Processing Record 11 of Set 12 | byron bay
# Processing Record 12 of Set 12 | honiara
# Processing Record 13 of Set 12 | flin flon
# Processing Record 14 of Set 12 | asau
# Processing Record 15 of Set 12 | xuddur
# Processing Record 16 of Set 12 | huarmey
# Processing Record 17 of Set 12 | cheremukhovo
# Processing Record 18 of Set 12 | poplar bluff
# Processing Record 19 of Set 12 | raymondville
# Processing Record 20 of Set 12 | san mateo del mar
# Processing Record 21 of Set 12 | henties bay
# Processing Record 22 of Set 12 | catarama
# Processing Record 23 of Set 12 | lazurne
# Processing Record 24 of Set 12 | varnavino
# Processing Record 25 of Set 12 | ouesso
# Processing Record 26 of Set 12 | waitati
# Processing Record 27 of Set 12 | gat
# Processing Record 28 of Set 12 | jacqueville
# Processing Record 29 of Set 12 | llodio
# Processing Record 30 of Set 12 | terrace bay
# Processing Record 31 of Set 12 | hirara
# Processing Record 32 of Set 12 | teya
# Processing Record 33 of Set 12 | leh
# Processing Record 34 of Set 12 | ye
# City not found. Skipping...
# Processing Record 35 of Set 12 | nizhniy kuranakh
# Processing Record 36 of Set 12 | sola
# Processing Record 37 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 12 | balabac
# Processing Record 39 of Set 12 | saint george
# Processing Record 40 of Set 12 | junin
# Processing Record 41 of Set 12 | umm lajj
# Processing Record 42 of Set 12 | beni suef
# Processing Record 43 of Set 12 | ancud
# Processing Record 44 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 12 | los zacatones
# Processing Record 46 of Set 12 | grindavik
# Processing Record 47 of Set 12 | christchurch
# Processing Record 48 of Set 12 | poum
# Processing Record 49 of Set 12 | kuala terengganu
# Processing Record 50 of Set 12 | petrykiv
# Processing Record 1 of Set 13 | baruun-urt
# Processing Record 2 of Set 13 | san pablo
# Processing Record 3 of Set 13 | gold coast
# Processing Record 4 of Set 13 | ulaangom
# Processing Record 5 of Set 13 | port-gentil
# Processing Record 6 of Set 13 | sturgeon bay
# Processing Record 7 of Set 13 | weimar
# Processing Record 8 of Set 13 | kokkola
# Processing Record 9 of Set 13 | riyadh
# Processing Record 10 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 12 of Set 13 | shimoda
# Processing Record 13 of Set 13 | ayutla
# Processing Record 14 of Set 13 | tazovskiy
# Processing Record 15 of Set 13 | pryozerne
# Processing Record 16 of Set 13 | agadez
# Processing Record 17 of Set 13 | sisimiut
# Processing Record 18 of Set 13 | moose factory
# Processing Record 19 of Set 13 | umea
# Processing Record 20 of Set 13 | santa helena
# Processing Record 21 of Set 13 | westport
# Processing Record 22 of Set 13 | bairiki
# Processing Record 23 of Set 13 | marmaron
# City not found. Skipping...
# Processing Record 24 of Set 13 | moerai
# Processing Record 25 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 13 | qasigiannguit
# Processing Record 27 of Set 13 | novoagansk
# Processing Record 28 of Set 13 | madera
# Processing Record 29 of Set 13 | baturaja
# Processing Record 30 of Set 13 | hasaki
# Processing Record 31 of Set 13 | daru
# Processing Record 32 of Set 13 | tadine
# Processing Record 33 of Set 13 | lithgow
# Processing Record 34 of Set 13 | ixtapa
# Processing Record 35 of Set 13 | aizawl
# Processing Record 36 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 13 | mafeteng
# Processing Record 38 of Set 13 | sorochinsk
# Processing Record 39 of Set 13 | mimongo
# Processing Record 40 of Set 13 | san-pedro
# Processing Record 41 of Set 13 | passo de camaragibe
# Processing Record 42 of Set 13 | peruc
# Processing Record 43 of Set 13 | dwarka
# Processing Record 44 of Set 13 | el alto
# Processing Record 45 of Set 13 | wanning
# Processing Record 46 of Set 13 | belaya gora
# Processing Record 47 of Set 13 | caucaia
# Processing Record 48 of Set 13 | rossland
# Processing Record 49 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 13 | naifaru
# Processing Record 1 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 14 | chekhov
# Processing Record 3 of Set 14 | akyab
# Processing Record 4 of Set 14 | pontianak
# Processing Record 5 of Set 14 | mandiana
# Processing Record 6 of Set 14 | yerkoy
# Processing Record 7 of Set 14 | shitanjing
# Processing Record 8 of Set 14 | kobryn
# Processing Record 9 of Set 14 | yegorlykskaya
# Processing Record 10 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 11 of Set 14 | truth or consequences
# Processing Record 12 of Set 14 | kurchum
# Processing Record 13 of Set 14 | inhambane
# Processing Record 14 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 14 | hermosillo
# Processing Record 16 of Set 14 | xichang
# Processing Record 17 of Set 14 | dicabisagan
# Processing Record 18 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 20 of Set 14 | okha
# Processing Record 21 of Set 14 | vieux-habitants
# Processing Record 22 of Set 14 | tomigusuku
# Processing Record 23 of Set 14 | skoghall
# Processing Record 24 of Set 14 | uthal
# Processing Record 25 of Set 14 | vestmanna
# Processing Record 26 of Set 14 | kaduqli
# Processing Record 27 of Set 14 | college
# Processing Record 28 of Set 14 | sangar
# Processing Record 29 of Set 14 | alegrete
# Processing Record 30 of Set 14 | aqtobe
# Processing Record 31 of Set 14 | mountain home
# Processing Record 32 of Set 14 | mehamn
# Processing Record 33 of Set 14 | kisaran
# Processing Record 34 of Set 14 | baranain
# Processing Record 35 of Set 14 | bandarbeyla
# Processing Record 36 of Set 14 | ngunguru
# Processing Record 37 of Set 14 | talaya
# Processing Record 38 of Set 14 | chany
# Processing Record 39 of Set 14 | lahij
# Processing Record 40 of Set 14 | issia
# Processing Record 41 of Set 14 | kenai
# Processing Record 42 of Set 14 | petrivka
# Processing Record 43 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 14 | pimentel
# Processing Record 45 of Set 14 | fort nelson
# Processing Record 46 of Set 14 | krasnoselkup
# Processing Record 47 of Set 14 | arzgir
# Processing Record 48 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 14 | tres passos
# Processing Record 50 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 1 of Set 15 | quelimane
# Processing Record 2 of Set 15 | revelstoke
# Processing Record 3 of Set 15 | brokopondo
# Processing Record 4 of Set 15 | shirokiy
# Processing Record 5 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 15 | norwich
# Processing Record 7 of Set 15 | anamur
# Processing Record 8 of Set 15 | kerema
# Processing Record 9 of Set 15 | vestmannaeyjar
# Processing Record 10 of Set 15 | raton
# Processing Record 11 of Set 15 | emba
# Processing Record 12 of Set 15 | derzhavinsk
# Processing Record 13 of Set 15 | tessalit
# Processing Record 14 of Set 15 | taoudenni
# Processing Record 15 of Set 15 | katsuura
# Processing Record 16 of Set 15 | pacific grove
# Processing Record 17 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 15 | batsfjord
# Processing Record 19 of Set 15 | yangambi
# Processing Record 20 of Set 15 | saint-augustin
# Processing Record 21 of Set 15 | kashi
# Processing Record 22 of Set 15 | wattegama
# Processing Record 23 of Set 15 | bathsheba
# Processing Record 24 of Set 15 | wakkanai
# Processing Record 25 of Set 15 | christiana
# Processing Record 26 of Set 15 | eirunepe
# Processing Record 27 of Set 15 | uusikaupunki
# Processing Record 28 of Set 15 | cacapava do sul
# Processing Record 29 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 15 | cerrik
# Processing Record 31 of Set 15 | hofn
# Processing Record 32 of Set 15 | antalaha
# Processing Record 33 of Set 15 | malacky
# Processing Record 34 of Set 15 | bolshaya sosnova
# Processing Record 35 of Set 15 | zarand
# Processing Record 36 of Set 15 | sabang
# Processing Record 37 of Set 15 | iquitos
# Processing Record 38 of Set 15 | neryungri
# Processing Record 39 of Set 15 | naze
# Processing Record 40 of Set 15 | haines junction
# Processing Record 41 of Set 15 | nenjiang
# Processing Record 42 of Set 15 | kalinovskoye
# Processing Record 43 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 15 | kapit
# Processing Record 45 of Set 15 | catamayo
# Processing Record 46 of Set 15 | hondo
# Processing Record 47 of Set 15 | berea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Upata   8.0086  -62.3989     75.00        85           2        7.00
# 1      Albany  42.6001  -73.9662     39.20        60          90        8.05
# 2     Rikitea -23.1203 -134.9692     79.86        80          87        9.51
# 3  Chokurdakh  70.6333  147.9167    -20.96        96         100       11.83
# 4   Busselton -33.6500  115.3333     68.00        93          54        1.99
# 5        Yaan   7.3833    8.5667     78.30        18         100        3.15
# 6    Hermanus -34.4187   19.2345     66.99        89         100        8.10
# 7  Nikolskoye  59.7035   30.7861     32.00        80          40       13.42
# 8     Ushuaia -54.8000  -68.3000     53.60        54          20        4.72
# 9       Kapaa  22.0752 -159.3190     75.20        60          20       19.57
#
#   Current Description
# 0           clear sky
# 1     overcast clouds
# 2     overcast clouds
# 3     overcast clouds
# 4          light rain
# 5     overcast clouds
# 6     overcast clouds
# 7    scattered clouds
# 8          few clouds
# 9          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
